# %%
# %run FingerCounter.py
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [classification {
#   index: 1
#   score: 0.875155508518219
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9068852066993713
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9055353999137878
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.8991109132766724
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9196299910545349
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
# ...
